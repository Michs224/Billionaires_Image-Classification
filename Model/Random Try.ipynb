# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# path 
path = "./geeks14.png"
   
# Reading an image in default mode
src = cv2.imread(path)
   
# Window name in which image is displayed
window_name = 'Image'
  
# Using cv2.cvtColor() method
# Using cv2.COLOR_BGR2GRAY color space
# conversion code

image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)
# Displaying the image 

cv2.imshow("image", image)
cv2.waitKey(0)

# Tutup semua jendela yang telah dibuka
cv2.destroyAllWindows()
plt.imshow(image,cmap="gray")

# %% [markdown]
# DataFrame,list zip

# %%
# Python program to demonstrate creating
# pandas Dataframe from lists using zip.

import pandas as pd

# List1
Name = ['tom', 'krish', 'nick', 'juli']

# List2
Age = [25, 30, 26, 22]

# get the list of tuples from two lists.
# and merge them by using zip().
list_of_tuples = pd.DataFrame(zip(Name, Age))


# Assign data to tuples.
list_of_tuples
# Out:
#        0   1
# 0    tom  25
# 1  krish  30
# 2   nick  26
# 3   juli  22

# %%
from bing_image_downloader import downloader

# %%
names=['Jim Walton',
 'Charles Koch',
 'Julia Koch',
 'Michael Bloomberg',
 'Larry Page',
 'Bernard Arnault',
 'Elon Musk',
 'Amancio Ortega',
 'Warren Buffett',
 'Mark Zuckerberg',
 'Rob Walton',
 'Zhong Shanshan',
 'Bill Gates',
 'Mukesh Ambani',
 'Carlos Slim Helu',
 'Jeff Bezos',
 'Larry Ellison',
 'Sergey Brin',
 'Francoise Bettencourt Meyers',
 'Steve Ballmer']

# %%
# for name in names:
downloader.download("Jack Ma",limit=70,adult_filter_off=True,output_dir='images')
# Out:
# [%] Downloading Images to C:\Users\user\Python\Projects\Actors and Actress - Image Classification\images\Jack Ma
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i2.wp.com/www.zambianobserver.com/wp-content/uploads/2020/03/http___prod-upp-image-read.ft_.jpeg?fit=2048%2C1152&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://fm.cnbc.com/applications/cnbc.com/resources/img/editorial/2017/01/18/104225995-_95A5004.1910x1000.jpg?v=1498058861
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.digitalcrew.com.au/wp-content/uploads/2018/09/jack-ma.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://corporate-executives.com/wp-content/uploads/2016/08/Jack-Ma.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://static.theprint.in/wp-content/uploads/2020/11/Jack-Ma-696x392.jpg
# [%] File Downloaded !
#
# ...

# %%
fruits = {"apple":[], "banana":[], "cherry":[]}

fruits["apple"].append("orange")

print(fruits)
# Out:
# {'apple': ['orange'], 'banana': [], 'cherry': []}
