# %%
# !pip install bing_image_downloader
from bing_image_downloader import downloader
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
names=['Jim Walton',
 'Charles Koch',
 'Julia Koch',
 'Michael Bloomberg',
 'Larry Page',
 'Bernard Arnault',
 'Elon Musk',
 'Amancio Ortega',
 'Warren Buffett',
 'Mark Zuckerberg',
 'Rob Walton',
 'Zhong Shanshan',
 'Bill Gates',
 'Mukesh Ambani',
 'Carlos Slim Helu',
 'Jeff Bezos',
 'Larry Ellison',
 'Sergey Brin',
 'Francoise Bettencourt Meyers',
 'Steve Ballmer']

# %%
for name in names:
    downloader.download(name,limit=120,adult_filter_off=True,output_dir='imagess')
# Out:
# [%] Downloading Images to d:\GitHub\Billionaires_Image-Classification\Model\imagess\Jim Walton
#
#
# [!!]Indexing page: 1
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 0 images.
# [%] Downloading Images to d:\GitHub\Billionaires_Image-Classification\Model\imagess\Charles Koch
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thelibertarianrepublic.com/wp-content/uploads/2016/02/635653973782783141-XXX-Charles-Koch-RD678.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.thefamouspeople.com/profiles/images/charles-koch-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://media.bizj.us/view/img/6745632/charles-koch*1200xx2048-1155-0-176.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("LarryPage",limit=120,adult_filter_off=True,output_dir='imagess')
# Out:
# [%] Downloading Images to d:\GitHub\Billionaires_Image-Classification\Model\imagess\LarryPage
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn1.i-scmp.com/sites/default/files/styles/1200x800/public/2014/03/20/larry_page.jpg?itok=5VApZyZf
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.topmost10.com/wp-content/uploads/2022/02/Larry-Page.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://marriedwikibio.com/wp-content/uploads/2020/12/Larry-Page.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.vox-cdn.com/thumbor/SagGpq_HYKhaPI-4PeLODXfuwdE=/0x0:1099x733/1200x800/filters:focal(0x0:1099x733)/cdn.vox-cdn.com/assets/1066989/dad.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://koniukhchaslau.com/wp-content/uploads/2020/09/larry-page-biography-1-1140x760.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("JimWalton Billionaire",limit=120,adult_filter_off=True,output_dir='imagess')
# Out:
# [%] Downloading Images to d:\GitHub\Billionaires_Image-Classification\Model\imagess\JimWalton Billionaire
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i1.wp.com/exploring-usa.com/wp-content/uploads/2018/10/1-Jim-Walton.jpg?resize=416%2C416
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://specials-images.forbesimg.com/imageserve/5d0292c7142c50000a32dd9a/960x0.jpg?cropX1=84&amp;cropX2=883&amp;cropY1=44&amp;cropY2=844
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.washingtonpost.com/graphics/politics/billionaires-who-matter-in-politics/img/billionaires.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://img.washingtonpost.com/rw/2010-2019/WashingtonPost/2012/03/07/National-Economy/Images/509249678.jpg?uuid=oar-YGh3EeGuP_AdkGeSuQ
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://live.staticflickr.com/2213/2388476804_585e85c482_b.jpg
# ...

# %%
downloader.download("Julia Koch Billionaire",limit=120,adult_filter_off=True,output_dir='imagess')
# Out:
# [%] Downloading Images to d:\GitHub\Billionaires_Image-Classification\Model\imagess\Julia Koch Billionaire
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.herworld.co.id/gallery/images/julia koch ok forb1.jpg
# [!] Issue getting: https://www.herworld.co.id/gallery/images/julia koch ok forb1.jpg
# [!] Error:: URL can't contain control characters. '/gallery/images/julia koch ok forb1.jpg' (found at least ' ')
# [%] Downloading Image #1 from https://caknowledge.com/wp-content/uploads/2021/12/Julia-Koch-Biography.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://vz.cnwimg.com/wp-content/uploads/2023/07/Julia-Koch-1153x1536.jpg?x82089
# [%] File Downloaded !
#
# ...
