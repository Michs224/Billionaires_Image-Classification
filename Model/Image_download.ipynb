# %%
import bing_image_downloader
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import bing_image_downloader
# ----> 2 downloader.download("Angelina Jolie", limit=40, output_dir="images", adult_filter_off=True)
#
# NameError: name 'downloader' is not defined

# %%
from bing_image_downloader import downloader
downloader.download("Tom Holland", limit=40, output_dir="images", adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\user\Python\Projects\Actors and Actress - Image Classification\images\Tom Holland
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://networthsize.com/wp-content/uploads/2020/04/Tom-Holland-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://image.tmdb.org/t/p/original/ip7aXVH8s6wXv8cY6KI14OZgCI8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Tom_Holland_by_Gage_Skidmore.jpg/1200px-Tom_Holland_by_Gage_Skidmore.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Tom_Holland_by_Gage_Skidmore.jpg/1200px-Tom_Holland_by_Gage_Skidmore.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Tom_Holland_by_Gage_Skidmore.jpg/1200px-Tom_Holland_by_Gage_Skidmore.jpg
# ...
